# %%
from matplotlib import rc
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# font_path = r"C:\Users\The9\AppData\Local\Microsoft\Windows\Fonts\NGULIM.TTF"
# font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
from matplotlib import font_manager, rc

# 폰트 파일 경로를 적절히 수정합니다.
font_path = "C:/Windows/Fonts/gulim.ttc"

# 폰트 이름을 가져옵니다.
fontprop = font_manager.FontProperties(fname=font_path)
font_name = fontprop.get_name()

# 폰트 설정을 변경합니다.
rc('font', family=font_name)

# %%
import numpy as np
data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([  86,   25,   81,   -8, -103,  -43, -115,  -19,   23,  -25, -100,
#        -173,  -80,  -39,  -52,  -17,   14,   50,   34,    5,  104,   86,
#          15,  -10,   88,   12,   -2,  -42,   -1,  -94, -112,  -47,   -5,
#          92,   12,   79,   -2,   69,   13,  -81,   -2,  -39,  -77, -141,
#        -224, -230, -190, -254, -209, -112])

# %%
plt.plot(range(50), data, 'r')
plt.title('가격변동 추이')
plt.ylabel('가격')
# Out:
# Text(0, 0.5, '가격')
